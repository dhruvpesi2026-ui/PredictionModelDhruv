# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('/content/diabetes.csv')

# %%
pd.read_csv?

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            4    143.7           77.7            0.0     45.9  38.1
# 1            4    195.5           67.6            0.0      0.0  37.6
# 2            5    108.7           33.2            0.0      0.0  46.3
# 3            1    106.5           76.1           22.2     22.3  26.6
# 4            7    123.8           33.8            6.9    109.5  33.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.370   46        0
# 1                     0.080   66        1
# 2                     0.439   23        1
# 3                     0.080   24        0
# 4                     0.197   21        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.010417  120.510807      65.679427      14.172656   52.170182
# std       1.721070   31.205064      22.436778      15.280252   75.771389
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       2.000000   99.175000      54.075000       0.000000    0.000000
# 50%       3.000000  121.350000      67.350000       9.950000   22.050000
# 75%       4.000000  142.025000      79.300000      25.225000   73.275000
# max       9.000000  199.000000     122.000000      71.900000  563.600000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.775000                  0.458740   33.102865    0.342448
# std      8.891549                  0.425776   13.561145    0.474838
# min      0.000000                  0.080000   21.000000    0.000000
# 25%     26.900000                  0.142750   21.000000    0.000000
# 50%     31.500000                  0.313000   29.000000    0.000000
# 75%     37.800000                  0.647500   40.000000    1.000000
# max     56.500000                  2.420000   81.000000    1.000000

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.010417  120.510807      65.679427      14.172656   52.170182
# std       1.721070   31.205064      22.436778      15.280252   75.771389
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       2.000000   99.175000      54.075000       0.000000    0.000000
# 50%       3.000000  121.350000      67.350000       9.950000   22.050000
# 75%       4.000000  142.025000      79.300000      25.225000   73.275000
# max       9.000000  199.000000     122.000000      71.900000  563.600000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.775000                  0.458740   33.102865    0.342448
# std      8.891549                  0.425776   13.561145    0.474838
# min      0.000000                  0.080000   21.000000    0.000000
# 25%     26.900000                  0.142750   21.000000    0.000000
# 50%     31.500000                  0.313000   29.000000    0.000000
# 75%     37.800000                  0.647500   40.000000    1.000000
# max     56.500000                  2.420000   81.000000    1.000000

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    505
# 1    263
# Name: count, dtype: int64

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness    Insulin  \
# Outcome
# 0           2.908911  114.982772      65.699802      13.131683  51.513069
# 1           3.205323  131.125475      65.640304      16.171483  53.431939
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        31.299406                  0.439608  31.651485
# 1        32.688213                  0.495475  35.889734

# %%
x=df.drop(columns='Outcome',axis=1)
y=df['Outcome']

# %%
print(x)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              4    143.7           77.7            0.0     45.9  38.1
# 1              4    195.5           67.6            0.0      0.0  37.6
# 2              5    108.7           33.2            0.0      0.0  46.3
# 3              1    106.5           76.1           22.2     22.3  26.6
# 4              7    123.8           33.8            6.9    109.5  33.7
# ..           ...      ...            ...            ...      ...   ...
# 763            2    133.5           89.1           41.6    102.1  42.1
# 764            3    137.5           74.2           31.4      0.0  41.7
# 765            2    154.9           33.8            4.3      0.0  46.9
# 766            2     90.0           50.6            3.5     40.0  31.9
# 767            8     91.0           79.7            0.0     15.5  21.8
#
#      DiabetesPedigreeFunction  Age
# 0                       0.370   46
# 1                       0.080   66
# 2                       0.439   23
# 3                       0.080   24
# 4                       0.197   21
# ..                        ...  ...
# 763                     0.213   33
# 764                     0.829   26
# 765                     0.567   36
# 766                     0.479   32
# 767                     0.586   63
#
# [768 rows x 8 columns]

# %%
print(y)
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    1
# 766    1
# 767    1
# Name: Outcome, Length: 768, dtype: int64

# %%
scaler=StandardScaler()

# %%
scaler.fit(x)
x_std=scaler.transform(x)

# %%
print(x_std)
# Out:
# [[ 0.57535618  0.74360702  0.53610221 ...  0.71181323 -0.20855445
#    0.95165563]
#  [ 0.57535618  2.40467579  0.0856551  ...  0.65554341 -0.89010813
#    2.42741843]
#  [ 1.15676874 -0.37873674 -1.448541   ...  1.63463829 -0.04639168
#   -0.74547158]
#  ...
#  [-0.58746894  1.10275703 -1.42178177 ...  1.70216207  0.25443202
#    0.21377423]
#  [-0.58746894 -0.97838898 -0.67252321 ...  0.01406746  0.04761573
#   -0.08137833]
#  [ 2.90100643 -0.94632201  0.62529966 ... -1.12258292  0.29908554
#    2.20605401]]

# %%
x=x_std

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %%
cf=svm.SVC(kernel='linear')

# %%
cf.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
x_train_pred=cf.predict(x_train)

# %%
x_train_acc=accuracy_score(x_train_pred,y_train)

# %%
print(x_train_acc)
# Out:
# 0.6954397394136808

# %%
x_test_pred=cf.predict(x_test)
x_test_acc=accuracy_score(x_test_pred,y_test)
print(x_test_acc)
# Out:
# 0.7077922077922078

# %%
input_data=[1,85,66,29,0,26.6,0.351,31]
print(input_data)
# Out:
# [1, 85, 66, 29, 0, 26.6, 0.351, 31]

# %%
data=np.asarray(input_data)
print(data)
# Out:
# [ 1.    85.    66.    29.     0.    26.6    0.351 31.   ]

# %%
data_reshape=data.reshape(1,-1)

# %%
input_std=scaler.transform(data_reshape)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
input_std = nput_std

# %%
print(input_std)
# Out:
# [[-1.16888151 -1.1387238   0.01429714  0.97099224 -0.68896956 -0.58239264
#   -0.25320797 -0.15516647]]

# %%
pred=cf.predict(input_std)
print(pred)
if(pred[0]==0):
  print('Non Diabetic')
else:
  print('Diabetic')
# Out:
# [0]
# Non Diabetic

# %%
import pickle

# %%
filename='trained_model(1).pkl'
pickle.dump(cf,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('trained_model(1).pkl','rb'))

# %%
input_data=[1,85,66,29,0,26.6,0.351,31]

data=np.asarray(input_data)

data_reshape=data.reshape(1,-1)

input_std=scaler.transform(data_reshape)
pred=loaded_model.predict(input_std)
print(pred)
if(pred[0]==0):
  print('Non Diabetic')
else:
  print('Diabetic')
# Out:
# [1]
# Diabetic

# %%
for col in df.columns:
  print(col)
# Out:
# Pregnancies
# Glucose
# BloodPressure
# SkinThickness
# Insulin
# BMI
# DiabetesPedigreeFunction
# Age
# Outcome

# %% [markdown]
# 2. House price Prediction

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
CSV_PATH = "/content/house_prices.csv"
RANDOM_STATE = 2

# %%
def load_data(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    print(f"Loaded {path} -> shape {df.shape}")
    return df

# %%
def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    before = len(df)
    df = df.drop_duplicates()
    if len(df) != before:
        print(f"Dropped {before - len(df)} duplicate rows")

    missing = df.isnull().sum()
    missing = missing[missing > 0]
    if len(missing):
        print(f"Filling missing values with column medians:\n{missing}")
        df = df.fillna(df.median(numeric_only=True))

    # Remove extreme price outliers using the IQR rule (catches the bad
    # data-entry rows where price was multiplied by a typo factor).
    q1, q3 = df["price"].quantile([0.25, 0.75])
    iqr = q3 - q1
    upper = q3 + 3 * iqr
    n_outliers = (df["price"] > upper).sum()
    if n_outliers:
        print(f"Removing {n_outliers} extreme price outlier(s) above {upper:,.0f}")
        df = df[df["price"] <= upper]

    return df

# %%
def preprocess(df: pd.DataFrame):
    X = df.drop(columns="price")
    y = df["price"]

    scaler = StandardScaler()
    scaler.fit(X)
    X_scaled = scaler.transform(X)

    return X_scaled, y, scaler, X.columns.tolist()

# %%
def train_model(X_train, y_train) -> RandomForestRegressor:
    model = RandomForestRegressor(
        n_estimators=200, max_depth=10, random_state=RANDOM_STATE
    )
    model.fit(X_train, y_train)
    return model

# %%
def evaluate(model, X_train, y_train, X_test, y_test):
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    train_r2 = r2_score(y_train, train_pred)
    test_r2 = r2_score(y_test, test_pred)
    mae = mean_absolute_error(y_test, test_pred)
    rmse = np.sqrt(mean_squared_error(y_test, test_pred))

    print(f"\nTraining R^2 : {train_r2:.4f}")
    print(f"Test R^2     : {test_r2:.4f}")
    print(f"Test MAE     : {mae:,.0f}")
    print(f"Test RMSE    : {rmse:,.0f}")

    cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
    print(f"5-fold CV R^2: {cv_scores.mean():.4f} (+/- {cv_scores.std():.4f})")

    return train_r2, test_r2

# %%
def predict_unseen_sample(model, scaler, feature_names):
    """A house listing that was never part of the CSV."""
    new_house = {
        "sqft_living": 2150, "bedrooms": 3, "bathrooms": 2.0, "floors": 2.0,
        "house_age": 8, "dist_to_city_km": 5.4, "quality_score": 7,
    }
    row = pd.DataFrame([new_house])[feature_names]
    row_scaled = scaler.transform(row)
    pred = model.predict(row_scaled)[0]

    print(f"\nUnseen sample input: {new_house}")
    print(f"Predicted price: ${pred:,.0f}")
    return pred

# %%
def main():
    df = load_data(CSV_PATH)
    df = clean_data(df)
    X, y, scaler, feature_names = preprocess(df)

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, random_state=RANDOM_STATE
    )
    print(f"Train/test shapes: {X_train.shape} / {X_test.shape}")

    model = train_model(X_train, y_train)
    train_r2, test_r2 = evaluate(model, X_train, y_train, X_test, y_test)
    predict_unseen_sample(model, scaler, feature_names)

    print(f"\nFinal prediction score (test R^2): {test_r2:.4f}")
    return test_r2

# %%
if __name__ == "__main__":
    main()
# Out:
# Loaded /content/house_prices.csv -> shape (1000, 8)
# Filling missing values with column medians:
# bathrooms    12
# dtype: int64
# Removing 3 extreme price outlier(s) above 939,799
# Train/test shapes: (797, 7) / (200, 7)
#
# Training R^2 : 0.9914
# Test R^2     : 0.9438
# Test MAE     : 21,730
# Test RMSE    : 27,115
# 5-fold CV R^2: 0.9435 (+/- 0.0105)
#
# Unseen sample input: {'sqft_living': 2150, 'bedrooms': 3, 'bathrooms': 2.0, 'floors': 2.0, 'house_age': 8, 'dist_to_city_km': 5.4, 'quality_score': 7}
# Predicted price: $455,584
#
# Final prediction score (test R^2): 0.9438
